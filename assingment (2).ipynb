# %%
[1].Guido Van Rossum developed the python programming language.

[2].python is a multi-paradigm programming language.object-orianted and structured programming are fully supported in python.

[3].Yes,paython is case-sensitive language,i.e., It treates uppercase and lowercase character differently.

[4].The correct extension of python file is .py 

[5].Python is interpreted language.

[6].Indentation is used to define a block of code in Python.Braces {} are used to define a block of code in most programming language.
    Example of python program showing use of indentation
        name='Alex'
        
        if name =='Alex':
            print('this is correct name')
        else:
            print('this is not correct name')
        print('hello')

[7]. We can write single-line comment by adding a single #.

[8].The function sys.version is used to defind a version of python in which we are currently working.

[9].Python supports the creation of anonymous functions at runtime , using a construct called "lamda".

[10].Pip stand for "Preferred installer program" in python.

[11].print( ) function
    input( ) function
    abs( ) function
    pow( ) function
    dir( ) function
    sorted( ) function
    max( ) function
    round( ) function
    divmod( ) function
    id( ) function
    ord( ) function
    len( ) function
    sum( ) function
    This all are some bult-in function in python.
    
[12].The maximum possible length of an integer is 79 Character.

[13].Data science
    Scientific and mathematical computing
    Web development
    Finance and trading
    System automation and administration
    Computer graphics
    Basic game development
    Security and penetration testing
    General and application-specific scripting
    Mapping and geography (GIS software)
    This all are the benefit of using python.
    
[14].Memory management in Python involves a private heap containing all Python objects and data structures. The management of this private heap is ensured internally by the Python memory manager.
    
[15].1.Right-clicking This PC and going to Properties.

    2.Clicking on the Advanced system settings in the menu on the left.

    3.Clicking on the Environment Variables button on the bottom right.

    4.In the System variables section, selecting the Path variable and clicking on Edit. The next screen will show all the directories that are currently a part of the PATH variable.

    5.Clicking on New and entering Python’s install directory.
    
[16].Indentation is a very important concept of python because without properly indenting the python code,you will end up seeing indentation Error and the code will not get complied.
